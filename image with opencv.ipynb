# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img=cv2.imread('./duck.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1024, 1024, 3)

# %%
plt.imshow(img)

# %%
fiximg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fiximg)

# %%
img_gray=cv2.imread('./duck.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='magma')

# %%
#resize
new_img=cv2.resize(fiximg,(800,400))
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (400, 800, 3)

# %%
w_ratio=1
h_ratio=1

new_img=cv2.resize(fiximg,(0,0),fiximg,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (1024, 1024, 3)

# %%
var_img=cv2.flip(fiximg,0)
plt.imshow(var_img)

# %%
type(var_img)
var_img1=cv2.cvtColor(var_img,cv2.COLOR_BGR2RGB)

# %%
cv2.imwrite('turnduck.png',var_img1)
# Out:
# True

# %%
fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)

ax.imshow(fiximg)

# %%
import cv2
img=cv2.imread('./duck.png')
cv2.imshow('duck',img)
cv2.waitKey()
# Out:
# -1

# %%
print('hello')
# Out:
# hello
